# %%
# !python cocotrain8-Copy2.py --config configs/mamba_vision/temp.py --bs 2 --accum 4
# Out:
# 📁 工作目录已准备就绪: /root/MambaVision/object_detection/work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128
# ✅ 检测到以下可用 GPU:
#     GPU 0: NVIDIA GeForce RTX 4090 D
#     GPU 1: NVIDIA GeForce RTX 4090 D
#     GPU 2: NVIDIA GeForce RTX 4090 D
# 🔧 未设置 CUDA_VISIBLE_DEVICES，脚本将默认使用所有检测到的物理 GPU。
# 🔧 将通过命令行覆盖配置文件中的 batch_size，设置为每张 GPU 2。
# 🚀 启用梯度累积！累积步数为 4。
#     等效全局 Batch Size ≈ 3 GPUs * 2 (per GPU) * 4 accum = 6 (approx)
# --------------------------------------------------
# 📌 最终使用的 GPU 数量: 3
# 📌 继承的 CUDA_VISIBLE_DEVICES: 未设置
# 📌 设置 PYTHONPATH = /root/MambaVision/object_detection
# 📂 脚本将在以下目录执行: /root/MambaVision/object_detection
# ⚙️  将执行以下命令:
#     torchrun --nproc-per-node=3 tools/train.py configs/mamba_vision/temp.py --launcher pytorch --work-dir work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128 --cfg-options train_dataloader.batch_size=2 optim_wrapper.accumulative_counts=4
# --------------------------------------------------
# ...
