# %%
# !python cocotrain8-Copy2.py --config configs/mamba_vision/temp.py --bs 2 --accum 2 --cfg-options train_cfg.max_epochs=25
# Out:
# 📁 工作目录已准备就绪: /root/MambaVision/object_detection/work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128
# ✅ 检测到以下可用 GPU:
#     GPU 0: NVIDIA GeForce RTX 4090 D
#     GPU 1: NVIDIA GeForce RTX 4090 D
#     GPU 2: NVIDIA GeForce RTX 4090 D
# 🔧 未设置 CUDA_VISIBLE_DEVICES，脚本将默认使用所有检测到的物理 GPU。
# 🔧 将通过命令行覆盖配置文件中的 batch_size，设置为每张 GPU 2。
# 🚀 启用梯度累积！累积步数为 2。
#     等效全局 Batch Size ≈ 3 GPUs * 2 (per GPU) * 2 accum = 6 (approx)
# 🔧 检测到并传递额外参数: --cfg-options train_cfg.max_epochs=21
# --------------------------------------------------
# 📌 最终使用的 GPU 数量: 3
# 📌 继承的 CUDA_VISIBLE_DEVICES: 未设置
# 📌 设置 PYTHONPATH = /root/MambaVision/object_detection
# 📂 脚本将在以下目录执行: /root/MambaVision/object_detection
# ⚙️  将执行以下命令:
#     torchrun --nproc-per-node=3 tools/train.py configs/mamba_vision/tempTransNeXt.py --launcher pytorch --work-dir work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128 --cfg-options train_dataloader.batch_size=2 optim_wrapper.accumulative_counts=2 --cfg-options train_cfg.max_epochs=21
# --------------------------------------------------
# /root/miniconda3/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# ✅ [Rank 0] 成功绑定到 GPU 0
# ✅ [Rank 1] 成功绑定到 GPU 1
# ✅ [Rank 2] 成功绑定到 GPU 2
# [LOAD CHECK] using NEW Shared2FCBrandHead (fp32 proto branch + safe cosine)
# [LOAD CHECK] using NEW Shared2FCBrandHead (fp32 proto branch + safe cosine)
# [LOAD CHECK] using NEW Shared2FCBrandHead (fp32 proto branch + safe cosine)
# 11/18 09:46:32 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.8 (main, Nov 24 2022, 14:13:03) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 42
#     GPU 0,1,2: NVIDIA GeForce RTX 4090 D
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2+cu121
#     OpenCV: 4.11.0
#     MMEngine: 0.10.1
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 42
#     Distributed launcher: pytorch
#     Distributed training: True
#     GPU number: 3
# ------------------------------------------------------------
#
# 11/18 09:46:34 - mmengine - INFO - Config:
# _batch_size_per_gpu = 4
# _gpu_count = 1
# _num_workers_per_gpu = 4
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# classes = [
#     'bolt1',
#     'bolt2',
#     'bolt3',
#     'bolt4',
#     'bolt5',
#     'bolt6',
#     'bolt7',
#     'bolt8',
#     'bolt9',
#     'bolt10',
#     'bolt11',
#     'bolt12',
#     'bolt13',
#     'bolt14',
# ]
# custom_imports = dict(
#     allow_failed_imports=False,
#     imports=[
#         'my_models.dual_task_detector',
#         'my_heads.custom_cascade_roi_head',
#         'my_heads.shared_2fc_brand_head',
#         'my_metrics.custom_brand_evaluator',
#         'my_metrics.custom_det_extra_evaluator',
#         'my_mmdet.datasets.custom_coco_dataset',
#         'my_mmdet.data_preprocessors.custom_data_preprocessor',
#         'my_backbones.TransNeXt',
#     ])
# data_preprocessor = dict(
#     bgr_to_rgb=False,
#     mean=[
#         103.53,
#         116.28,
#         123.675,
#     ],
#     pad_size_divisor=32,
#     std=[
#         57.375,
#         57.12,
#         58.395,
#     ],
#     type='CustomDetDataPreprocessor')
# data_root = '/root/autodl-tmp/coco_dataset2/'
# dataset_type = 'CustomCocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=3,
#         rule='greater',
#         save_best='auto',
#         type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=True, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'pytorch'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# model = dict(
#     backbone=dict(
#         depths=(
#             1,
#             3,
#             8,
#             4,
#         ),
#         dim=80,
#         drop_path_rate=0.2,
#         enable_pcs=True,
#         enable_sac=True,
#         enable_sl_bridge=False,
#         in_dim=32,
#         layer_scale=None,
#         mlp_ratio=4,
#         norm_layer='ln2d',
#         num_heads=(
#             2,
#             4,
#             8,
#             16,
#         ),
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         pretrained=None,
#         type='MM_TransNeXt',
#         use_checkpoint=False,
#         window_size=(
#             8,
#             8,
#             8,
#             8,
#         )),
#     brand_head=dict(
#         fc_out_channels=1024,
#         film_from_fourdir=True,
#         fourdir_hidden=256,
#         in_channels=256,
#         loss_cls=dict(
#             loss_weight=1.0,
#             reduction='mean',
#             type='CrossEntropyLoss',
#             use_sigmoid=False),
#         num_classes=7,
#         proto_dim=None,
#         proto_lambda=0.3,
#         proto_tau=10.0,
#         state_dim=256,
#         state_hidden=256,
#         type='Shared2FCBrandHead',
#         use_four_dir_squeeze=True,
#         use_prototype_branch=True,
#         use_state_condition=True),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     loss_weight_brand=0.5,
#     neck=dict(
#         in_channels=[
#             80,
#             160,
#             320,
#             640,
#         ],
#         num_outs=4,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=10.0, type='GIoULoss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 norm_cfg=dict(num_groups=32, requires_grad=True, type='GN'),
#                 num_classes=14,
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 roi_feat_size=7,
#                 type='ConvFCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=10.0, type='GIoULoss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 norm_cfg=dict(num_groups=32, requires_grad=True, type='GN'),
#                 num_classes=14,
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 roi_feat_size=7,
#                 type='ConvFCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=10.0, type='GIoULoss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 norm_cfg=dict(num_groups=32, requires_grad=True, type='GN'),
#                 num_classes=14,
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 roi_feat_size=7,
#                 type='ConvFCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         fourdir_hidden=256,
#         num_stages=3,
#         rel_alpha=0.5,
#         rel_k=6,
#         roi_feat_channels=256,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         state_hidden=256,
#         state_in_channels=256,
#         test_cfg=dict(
#             rcnn=dict(
#                 max_per_img=100,
#                 nms=dict(iou_threshold=0.5, type='nms'),
#                 score_thr=0.05)),
#         train_cfg=dict(rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=256,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=256,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=256,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ]),
#         type='CustomCascadeRoIHead',
#         use_external_state=False,
#         use_four_dir_pool=True,
#         use_relation_refine=True,
#         use_state_condition=True),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         output_brand_score=True,
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     type='DualTaskDetector')
# model_wrapper_cfg = dict(
#     find_unused_parameters=True, type='MMDistributedDataParallel')
# optim_wrapper = dict(
#     accumulative_counts=2,
#     clip_grad=dict(max_norm=1.0, norm_type=2),
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=0.0001, type='AdamW', weight_decay=0.05),
#     paramwise_cfg=dict(custom_keys=dict(norm=dict(decay_mult=0.0))),
#     type='AmpOptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# randomness = dict(seed=42)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=4,
#     collate_fn=dict(type='pseudo_collate'),
#     dataset=dict(
#         ann_file='annotations/val.json',
#         backend_args=None,
#         data_prefix=dict(img='images/val'),
#         data_root='/root/autodl-tmp/coco_dataset2/',
#         metainfo=dict(classes=[
#             'bolt1',
#             'bolt2',
#             'bolt3',
#             'bolt4',
#             'bolt5',
#             'bolt6',
#             'bolt7',
#             'bolt8',
#             'bolt9',
#             'bolt10',
#             'bolt11',
#             'bolt12',
#             'bolt13',
#             'bolt14',
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 900,
#                 608,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=False),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'brand_id',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CustomCocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(
#         ann_file='/root/autodl-tmp/coco_dataset2/annotations/val.json',
#         backend_args=None,
#         format_only=False,
#         metric=[
#             'bbox',
#         ],
#         type='CocoMetric'),
#     dict(by_epoch=True, topk=(
#         1,
#         5,
#     ), type='CustomBrandEvaluator'),
#     dict(
#         iou_thrs=(0.5, ),
#         report_cls_acc=True,
#         report_tp_mean_iou=True,
#         type='CustomDetExtraEvaluator'),
# ]
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         900,
#         608,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=False),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'brand_id',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=21, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     collate_fn=dict(type='pseudo_collate'),
#     dataset=dict(
#         ann_file='annotations/train.json',
#         backend_args=None,
#         data_prefix=dict(img='images/train'),
#         data_root='/root/autodl-tmp/coco_dataset2/',
#         metainfo=dict(classes=[
#             'bolt1',
#             'bolt2',
#             'bolt3',
#             'bolt4',
#             'bolt5',
#             'bolt6',
#             'bolt7',
#             'bolt8',
#             'bolt9',
#             'bolt10',
#             'bolt11',
#             'bolt12',
#             'bolt13',
#             'bolt14',
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=False),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(
#                 transforms=[
#                     [
#                         dict(
#                             keep_ratio=True,
#                             scales=[
#                                 (
#                                     480,
#                                     900,
#                                 ),
#                                 (
#                                     512,
#                                     900,
#                                 ),
#                                 (
#                                     544,
#                                     900,
#                                 ),
#                                 (
#                                     576,
#                                     900,
#                                 ),
#                                 (
#                                     608,
#                                     900,
#                                 ),
#                                 (
#                                     640,
#                                     900,
#                                 ),
#                             ],
#                             type='RandomChoiceResize'),
#                     ],
#                 ],
#                 type='RandomChoice'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'brand_id',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         type='CustomCocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=False),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(
#         transforms=[
#             [
#                 dict(
#                     keep_ratio=True,
#                     scales=[
#                         (
#                             480,
#                             900,
#                         ),
#                         (
#                             512,
#                             900,
#                         ),
#                         (
#                             544,
#                             900,
#                         ),
#                         (
#                             576,
#                             900,
#                         ),
#                         (
#                             608,
#                             900,
#                         ),
#                         (
#                             640,
#                             900,
#                         ),
#                     ],
#                     type='RandomChoiceResize'),
#             ],
#         ],
#         type='RandomChoice'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'brand_id',
#         ),
#         type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=4,
#     collate_fn=dict(type='pseudo_collate'),
#     dataset=dict(
#         ann_file='annotations/val.json',
#         backend_args=None,
#         data_prefix=dict(img='images/val'),
#         data_root='/root/autodl-tmp/coco_dataset2/',
#         metainfo=dict(classes=[
#             'bolt1',
#             'bolt2',
#             'bolt3',
#             'bolt4',
#             'bolt5',
#             'bolt6',
#             'bolt7',
#             'bolt8',
#             'bolt9',
#             'bolt10',
#             'bolt11',
#             'bolt12',
#             'bolt13',
#             'bolt14',
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 900,
#                 608,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=False),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'brand_id',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CustomCocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = [
#     dict(
#         ann_file='/root/autodl-tmp/coco_dataset2/annotations/val.json',
#         backend_args=None,
#         format_only=False,
#         metric=[
#             'bbox',
#         ],
#         type='CocoMetric'),
#     dict(by_epoch=True, topk=(
#         1,
#         5,
#     ), type='CustomBrandEvaluator'),
#     dict(
#         iou_thrs=(0.5, ),
#         report_cls_acc=True,
#         report_tp_mean_iou=True,
#         type='CustomDetExtraEvaluator'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = 'work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128'
#
# [INFO] Created state_projector: 256 -> 256
# [INFO] Created fourdir_gate: channels=256
# [INFO] Created state_projector: 256 -> 256
# [INFO] Created fourdir_gate: channels=256
# [INFO] Created state_projector: 256 -> 256
# [INFO] Created fourdir_gate: channels=256
# 11/18 09:46:38 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.64s)
# creating index...
# Done (t=0.64s)
# creating index...
# index created!
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.50s)
# creating index...
# Done (t=0.50s)
# creating index...
# index created!
# index created!
# loading annotations into memory...
# Done (t=0.45s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# Done (t=0.06s)
# creating index...
# index created!
# index created!
# Done (t=0.48s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# Done (t=0.07s)
# creating index...
# index created!
# index created!
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.2.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:weight_decay=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:decay_mult=0.0
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:lr=0.0001
# 11/18 09:46:42 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:weight_decay=0.0
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.829
# 11/18 18:26:24 - mmengine - INFO - bbox_mAP_copypaste: 0.679 0.864 0.809 0.000 0.534 0.792
# 11/18 18:26:24 - mmengine - INFO - Epoch(val) [20][179/179]    coco/bbox_mAP: 0.6790  coco/bbox_mAP_50: 0.8640  coco/bbox_mAP_75: 0.8090  coco/bbox_mAP_s: 0.0000  coco/bbox_mAP_m: 0.5340  coco/bbox_mAP_l: 0.7920  brand_top1_acc: 0.0000  brand_top5_acc: 0.0000  brand_macro_precision: 0.0000  brand_macro_recall: 0.0000  brand_macro_f1: 0.0000  det/det/matched_cls_acc@0.50: 0.0000  det/det/tp_mean_iou@0.50: 0.0000  data_time: 0.0077  time: 0.6501
# 11/18 18:27:15 - mmengine - INFO - Epoch(train) [21][  50/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:22:54  time: 1.0074  data_time: 0.0220  memory: 7651  loss: 0.3157  loss_rpn_cls: 0.0038  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0320  s0.acc: 98.4375  s0.loss_bbox: 0.1365  s1.loss_cls: 0.0071  s1.acc: 99.3164  s1.loss_bbox: 0.0883  s2.loss_cls: 0.0035  s2.acc: 99.4123  s2.loss_bbox: 0.0437  loss_brand_cls: 0.0001  grad_norm: 2.5037
# 11/18 18:28:05 - mmengine - INFO - Epoch(train) [21][ 100/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:22:04  time: 1.0053  data_time: 0.0108  memory: 7654  loss: 0.3284  loss_rpn_cls: 0.0054  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.0345  s0.acc: 99.1211  s0.loss_bbox: 0.1429  s1.loss_cls: 0.0076  s1.acc: 99.3164  s1.loss_bbox: 0.0891  s2.loss_cls: 0.0038  s2.acc: 99.7070  s2.loss_bbox: 0.0444  loss_brand_cls: 0.0000  grad_norm: 2.5061
# 11/18 18:28:55 - mmengine - INFO - Epoch(train) [21][ 150/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:21:14  time: 1.0081  data_time: 0.0107  memory: 7652  loss: 0.3338  loss_rpn_cls: 0.0059  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0294  s0.acc: 97.6562  s0.loss_bbox: 0.1531  s1.loss_cls: 0.0067  s1.acc: 99.7998  s1.loss_bbox: 0.0901  s2.loss_cls: 0.0031  s2.acc: 99.3909  s2.loss_bbox: 0.0446  loss_brand_cls: 0.0000  grad_norm: 2.3606
# 11/18 18:29:46 - mmengine - INFO - Epoch(train) [21][ 200/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:20:25  time: 1.0057  data_time: 0.0110  memory: 7669  loss: 0.3271  loss_rpn_cls: 0.0040  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0309  s0.acc: 99.0234  s0.loss_bbox: 0.1453  s1.loss_cls: 0.0067  s1.acc: 100.0000  s1.loss_bbox: 0.0908  s2.loss_cls: 0.0030  s2.acc: 100.0000  s2.loss_bbox: 0.0456  loss_brand_cls: 0.0000  grad_norm: 2.3314
# 11/18 18:30:36 - mmengine - INFO - Epoch(train) [21][ 250/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:19:35  time: 1.0041  data_time: 0.0110  memory: 7667  loss: 0.3494  loss_rpn_cls: 0.0043  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0354  s0.acc: 98.9258  s0.loss_bbox: 0.1543  s1.loss_cls: 0.0082  s1.acc: 99.5964  s1.loss_bbox: 0.0945  s2.loss_cls: 0.0047  s2.acc: 99.4893  s2.loss_bbox: 0.0469  loss_brand_cls: 0.0001  grad_norm: 2.2977
# 11/18 18:31:26 - mmengine - INFO - Epoch(train) [21][ 300/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:18:45  time: 1.0088  data_time: 0.0108  memory: 7666  loss: 0.3276  loss_rpn_cls: 0.0044  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0323  s0.acc: 98.6328  s0.loss_bbox: 0.1438  s1.loss_cls: 0.0072  s1.acc: 99.4065  s1.loss_bbox: 0.0900  s2.loss_cls: 0.0041  s2.acc: 99.5030  s2.loss_bbox: 0.0451  loss_brand_cls: 0.0000  grad_norm: 2.2928
# 11/18 18:32:16 - mmengine - INFO - Epoch(train) [21][ 350/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:17:55  time: 1.0017  data_time: 0.0107  memory: 7665  loss: 0.3389  loss_rpn_cls: 0.0049  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0337  s0.acc: 98.5352  s0.loss_bbox: 0.1469  s1.loss_cls: 0.0081  s1.acc: 99.7070  s1.loss_bbox: 0.0932  s2.loss_cls: 0.0063  s2.acc: 99.7070  s2.loss_bbox: 0.0451  loss_brand_cls: 0.0001  grad_norm: 2.3652
# 11/18 18:33:06 - mmengine - INFO - Epoch(train) [21][ 400/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:17:05  time: 0.9981  data_time: 0.0107  memory: 7666  loss: 0.3446  loss_rpn_cls: 0.0061  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0347  s0.acc: 98.2422  s0.loss_bbox: 0.1479  s1.loss_cls: 0.0084  s1.acc: 99.1185  s1.loss_bbox: 0.0952  s2.loss_cls: 0.0040  s2.acc: 99.6036  s2.loss_bbox: 0.0473  loss_brand_cls: 0.0000  grad_norm: 2.3922
# 11/18 18:33:26 - mmengine - INFO - Exp name: tempTransNeXt_20251118_094631
# 11/18 18:33:56 - mmengine - INFO - Epoch(train) [21][ 450/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:16:15  time: 0.9911  data_time: 0.0108  memory: 7666  loss: 0.3215  loss_rpn_cls: 0.0056  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.0312  s0.acc: 98.2422  s0.loss_bbox: 0.1416  s1.loss_cls: 0.0079  s1.acc: 99.2843  s1.loss_bbox: 0.0869  s2.loss_cls: 0.0039  s2.acc: 99.2798  s2.loss_bbox: 0.0433  loss_brand_cls: 0.0002  grad_norm: 2.3981
# 11/18 18:34:47 - mmengine - INFO - Epoch(train) [21][ 500/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:15:26  time: 1.0169  data_time: 0.0110  memory: 7669  loss: 0.3169  loss_rpn_cls: 0.0056  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0300  s0.acc: 98.8281  s0.loss_bbox: 0.1391  s1.loss_cls: 0.0066  s1.acc: 99.6094  s1.loss_bbox: 0.0876  s2.loss_cls: 0.0037  s2.acc: 99.9023  s2.loss_bbox: 0.0435  loss_brand_cls: 0.0000  grad_norm: 2.3202
# 11/18 18:35:36 - mmengine - INFO - Epoch(train) [21][ 550/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:14:36  time: 0.9928  data_time: 0.0110  memory: 7667  loss: 0.3401  loss_rpn_cls: 0.0053  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0299  s0.acc: 99.2188  s0.loss_bbox: 0.1508  s1.loss_cls: 0.0073  s1.acc: 100.0000  s1.loss_bbox: 0.0953  s2.loss_cls: 0.0034  s2.acc: 99.9023  s2.loss_bbox: 0.0473  loss_brand_cls: 0.0000  grad_norm: 2.2894
# 11/18 18:36:28 - mmengine - INFO - Epoch(train) [21][ 600/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:13:46  time: 1.0258  data_time: 0.0110  memory: 7667  loss: 0.2928  loss_rpn_cls: 0.0041  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.0289  s0.acc: 99.2188  s0.loss_bbox: 0.1295  s1.loss_cls: 0.0054  s1.acc: 99.7070  s1.loss_bbox: 0.0809  s2.loss_cls: 0.0028  s2.acc: 99.8045  s2.loss_bbox: 0.0404  loss_brand_cls: 0.0000  grad_norm: 2.3081
# 11/18 18:37:19 - mmengine - INFO - Epoch(train) [21][ 650/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:12:56  time: 1.0263  data_time: 0.0107  memory: 7668  loss: 0.3444  loss_rpn_cls: 0.0062  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0376  s0.acc: 98.4375  s0.loss_bbox: 0.1450  s1.loss_cls: 0.0112  s1.acc: 99.4781  s1.loss_bbox: 0.0920  s2.loss_cls: 0.0057  s2.acc: 99.5758  s2.loss_bbox: 0.0458  loss_brand_cls: 0.0000  grad_norm: 2.3321
# 11/18 18:38:09 - mmengine - INFO - Epoch(train) [21][ 700/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:12:06  time: 0.9925  data_time: 0.0106  memory: 7665  loss: 0.3157  loss_rpn_cls: 0.0059  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0348  s0.acc: 98.0469  s0.loss_bbox: 0.1325  s1.loss_cls: 0.0104  s1.acc: 99.4861  s1.loss_bbox: 0.0839  s2.loss_cls: 0.0050  s2.acc: 99.6881  s2.loss_bbox: 0.0411  loss_brand_cls: 0.0013  grad_norm: 2.4470
# 11/18 18:39:01 - mmengine - INFO - Epoch(train) [21][ 750/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:11:16  time: 1.0545  data_time: 0.0110  memory: 7976  loss: 0.3644  loss_rpn_cls: 0.0086  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0412  s0.acc: 98.7305  s0.loss_bbox: 0.1534  s1.loss_cls: 0.0108  s1.acc: 99.2188  s1.loss_bbox: 0.0963  s2.loss_cls: 0.0056  s2.acc: 98.7305  s2.loss_bbox: 0.0476  loss_brand_cls: 0.0000  grad_norm: 2.4363
# 11/18 18:39:51 - mmengine - INFO - Epoch(train) [21][ 800/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:10:27  time: 0.9982  data_time: 0.0107  memory: 7662  loss: 0.3383  loss_rpn_cls: 0.0039  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0335  s0.acc: 98.9258  s0.loss_bbox: 0.1500  s1.loss_cls: 0.0075  s1.acc: 99.2901  s1.loss_bbox: 0.0930  s2.loss_cls: 0.0036  s2.acc: 99.3789  s2.loss_bbox: 0.0462  loss_brand_cls: 0.0000  grad_norm: 2.4006
# 11/18 18:40:42 - mmengine - INFO - Epoch(train) [21][ 850/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:09:37  time: 1.0069  data_time: 0.0106  memory: 7668  loss: 0.3224  loss_rpn_cls: 0.0042  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.0338  s0.acc: 99.3164  s0.loss_bbox: 0.1393  s1.loss_cls: 0.0089  s1.acc: 99.7070  s1.loss_bbox: 0.0875  s2.loss_cls: 0.0041  s2.acc: 99.5117  s2.loss_bbox: 0.0439  loss_brand_cls: 0.0000  grad_norm: 2.3733
# 11/18 18:41:32 - mmengine - INFO - Epoch(train) [21][ 900/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:08:47  time: 1.0012  data_time: 0.0106  memory: 7661  loss: 0.3220  loss_rpn_cls: 0.0049  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0330  s0.acc: 98.7305  s0.loss_bbox: 0.1408  s1.loss_cls: 0.0079  s1.acc: 99.9023  s1.loss_bbox: 0.0870  s2.loss_cls: 0.0043  s2.acc: 99.6094  s2.loss_bbox: 0.0432  loss_brand_cls: 0.0000  grad_norm: 2.3782
# 11/18 18:42:22 - mmengine - INFO - Epoch(train) [21][ 950/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:07:57  time: 0.9957  data_time: 0.0107  memory: 7664  loss: 0.3272  loss_rpn_cls: 0.0045  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.0327  s0.acc: 99.4141  s0.loss_bbox: 0.1422  s1.loss_cls: 0.0068  s1.acc: 100.0000  s1.loss_bbox: 0.0910  s2.loss_cls: 0.0033  s2.acc: 99.7986  s2.loss_bbox: 0.0456  loss_brand_cls: 0.0005  grad_norm: 2.3944
# 11/18 18:43:12 - mmengine - INFO - Epoch(train) [21][1000/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:07:07  time: 1.0007  data_time: 0.0107  memory: 7651  loss: 0.3343  loss_rpn_cls: 0.0050  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0334  s0.acc: 99.4141  s0.loss_bbox: 0.1455  s1.loss_cls: 0.0066  s1.acc: 99.4141  s1.loss_bbox: 0.0931  s2.loss_cls: 0.0028  s2.acc: 99.7036  s2.loss_bbox: 0.0470  loss_brand_cls: 0.0000  grad_norm: 2.3553
# 11/18 18:44:02 - mmengine - INFO - Epoch(train) [21][1050/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:06:17  time: 1.0019  data_time: 0.0104  memory: 7669  loss: 0.3192  loss_rpn_cls: 0.0039  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.0302  s0.acc: 98.8281  s0.loss_bbox: 0.1401  s1.loss_cls: 0.0065  s1.acc: 99.4048  s1.loss_bbox: 0.0896  s2.loss_cls: 0.0029  s2.acc: 99.6008  s2.loss_bbox: 0.0452  loss_brand_cls: 0.0001  grad_norm: 2.3251
# 11/18 18:44:52 - mmengine - INFO - Epoch(train) [21][1100/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:05:28  time: 0.9994  data_time: 0.0106  memory: 7665  loss: 0.3373  loss_rpn_cls: 0.0056  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0347  s0.acc: 98.2422  s0.loss_bbox: 0.1465  s1.loss_cls: 0.0085  s1.acc: 99.5976  s1.loss_bbox: 0.0913  s2.loss_cls: 0.0039  s2.acc: 99.8990  s2.loss_bbox: 0.0457  loss_brand_cls: 0.0000  grad_norm: 2.3414
# 11/18 18:45:41 - mmengine - INFO - Epoch(train) [21][1150/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:04:38  time: 0.9971  data_time: 0.0107  memory: 7656  loss: 0.3426  loss_rpn_cls: 0.0033  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0351  s0.acc: 97.9492  s0.loss_bbox: 0.1484  s1.loss_cls: 0.0084  s1.acc: 98.9605  s1.loss_bbox: 0.0949  s2.loss_cls: 0.0043  s2.acc: 99.2521  s2.loss_bbox: 0.0474  loss_brand_cls: 0.0000  grad_norm: 2.3856
# 11/18 18:46:31 - mmengine - INFO - Epoch(train) [21][1200/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:03:48  time: 0.9973  data_time: 0.0106  memory: 7658  loss: 0.3390  loss_rpn_cls: 0.0045  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0336  s0.acc: 97.6562  s0.loss_bbox: 0.1468  s1.loss_cls: 0.0089  s1.acc: 99.1211  s1.loss_bbox: 0.0933  s2.loss_cls: 0.0055  s2.acc: 99.6040  s2.loss_bbox: 0.0456  loss_brand_cls: 0.0000  grad_norm: 2.3396
# 11/18 18:47:22 - mmengine - INFO - Epoch(train) [21][1250/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:02:58  time: 1.0037  data_time: 0.0107  memory: 7659  loss: 0.3382  loss_rpn_cls: 0.0047  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0330  s0.acc: 97.6562  s0.loss_bbox: 0.1497  s1.loss_cls: 0.0061  s1.acc: 98.6328  s1.loss_bbox: 0.0940  s2.loss_cls: 0.0033  s2.acc: 97.3633  s2.loss_bbox: 0.0466  loss_brand_cls: 0.0000  grad_norm: 2.3272
# 11/18 18:48:11 - mmengine - INFO - Epoch(train) [21][1300/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:02:08  time: 0.9899  data_time: 0.0106  memory: 7663  loss: 0.3230  loss_rpn_cls: 0.0068  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0305  s0.acc: 99.3164  s0.loss_bbox: 0.1396  s1.loss_cls: 0.0073  s1.acc: 99.9023  s1.loss_bbox: 0.0896  s2.loss_cls: 0.0034  s2.acc: 100.0000  s2.loss_bbox: 0.0450  loss_brand_cls: 0.0000  grad_norm: 2.3633
# 11/18 18:49:01 - mmengine - INFO - Epoch(train) [21][1350/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:01:18  time: 0.9958  data_time: 0.0107  memory: 7664  loss: 0.3608  loss_rpn_cls: 0.0040  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.0379  s0.acc: 98.5352  s0.loss_bbox: 0.1455  s1.loss_cls: 0.0102  s1.acc: 99.5943  s1.loss_bbox: 0.0901  s2.loss_cls: 0.0047  s2.acc: 99.6914  s2.loss_bbox: 0.0448  loss_brand_cls: 0.0228  grad_norm: 2.4577
# 11/18 18:49:52 - mmengine - INFO - Epoch(train) [21][1400/1429]  base_lr: 1.0000e-06 lr: 1.0000e-06  eta: 0:00:28  time: 1.0177  data_time: 0.0107  memory: 7659  loss: 0.3342  loss_rpn_cls: 0.0068  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0317  s0.acc: 98.7305  s0.loss_bbox: 0.1486  s1.loss_cls: 0.0065  s1.acc: 99.2693  s1.loss_bbox: 0.0912  s2.loss_cls: 0.0033  s2.acc: 99.2521  s2.loss_bbox: 0.0452  loss_brand_cls: 0.0000  grad_norm: 2.4565
# 11/18 18:50:14 - mmengine - INFO - Exp name: tempTransNeXt_20251118_094631
# 11/18 18:50:25 - mmengine - INFO - Exp name: tempTransNeXt_20251118_094631
# 11/18 18:50:25 - mmengine - INFO - Saving checkpoint at 21 epochs
# 11/18 18:51:02 - mmengine - INFO - Epoch(val) [21][ 50/179]    eta: 0:01:24  time: 0.6584  data_time: 0.0128  memory: 8874
# 11/18 18:51:36 - mmengine - INFO - Epoch(val) [21][100/179]    eta: 0:00:52  time: 0.6755  data_time: 0.0061  memory: 3196
# 11/18 18:52:07 - mmengine - INFO - Epoch(val) [21][150/179]    eta: 0:00:18  time: 0.6199  data_time: 0.0061  memory: 2731
# 11/18 18:52:25 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=6.47s).
# Accumulating evaluation results...
# DONE (t=0.75s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.678
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.865
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.792
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.831
# 11/18 18:52:32 - mmengine - INFO - bbox_mAP_copypaste: 0.678 0.865 0.811 0.000 0.528 0.792
# 11/18 18:52:32 - mmengine - INFO - Epoch(val) [21][179/179]    coco/bbox_mAP: 0.6780  coco/bbox_mAP_50: 0.8650  coco/bbox_mAP_75: 0.8110  coco/bbox_mAP_s: 0.0000  coco/bbox_mAP_m: 0.5280  coco/bbox_mAP_l: 0.7920  brand_top1_acc: 0.0000  brand_top5_acc: 0.0000  brand_macro_precision: 0.0000  brand_macro_recall: 0.0000  brand_macro_f1: 0.0000  det/det/matched_cls_acc@0.50: 0.0000  det/det/tp_mean_iou@0.50: 0.0000  data_time: 0.0080  time: 0.6434
#
# ✅ 训练过程成功完成!
#
# 📈 训练已完成，开始进行日志分析和图表生成...
# 🔎 正在解析日志文件: work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128/20251118_094631/vis_data/scalars.json
# ✅ 已生成 Loss 曲线图: work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128/20251118_094631/loss_curve.png
# ✅ 已生成 mAP 曲线图: work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128/20251118_094631/mAP_curve.png
# ✅ 已生成训练摘要: work_dirs/cascade_mask_rcnn_mamba_vision_tiny_3x_coco128/20251118_094631/summary.txt
#
# ⏱️  总任务耗时: 9.10 小时 (32777.56 秒)
