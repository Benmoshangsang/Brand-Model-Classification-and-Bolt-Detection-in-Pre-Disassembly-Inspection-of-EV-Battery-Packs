# %%
import json

def inspect_coco_json(json_path):
    print(f"\n🔍 正在检查文件: {json_path}")
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # 检查 images 字段
    print("\n📁 [images] 中的字段:")
    if 'images' in data and isinstance(data['images'], list):
        image_keys = set()
        for img in data['images']:
            image_keys.update(img.keys())
        print("字段集合:", image_keys)
        brand_image_missing = sum(1 for img in data['images'] if 'brand_id' not in img)
        print(f"⚠️ 缺失 brand_id 的 images 条目数: {brand_image_missing}")
    else:
        print("❌ 未找到 images 字段")

    # 检查 annotations 字段
    print("\n📁 [annotations] 中的字段:")
    if 'annotations' in data and isinstance(data['annotations'], list):
        anno_keys = set()
        for anno in data['annotations']:
            anno_keys.update(anno.keys())
        print("字段集合:", anno_keys)
        brand_anno_missing = sum(1 for anno in data['annotations'] if 'brand_id' not in anno)
        print(f"⚠️ 缺失 brand_id 的 annotations 条目数: {brand_anno_missing}")
    else:
        print("❌ 未找到 annotations 字段")

    # 类别字段
    print("\n📁 [categories] 类别数:", len(data.get('categories', [])))

# 路径配置
paths = {
    'train': '/root/autodl-tmp/coco_dataset/annotations/train.json',
    'val': '/root/autodl-tmp/coco_dataset/annotations/val.json'
}

# 执行检查
for name, path in paths.items():
    inspect_coco_json(path)
# Out:
# 📁 正在查看: train 数据集 -> train.json
# ✅ 顶级字段: ['images', 'annotations', 'categories']
#
# 🔹 字段: images
#    共 1165 项，前 3 项如下：
#    1. {'id': 0, 'file_name': 'IMG_6527.JPG', 'height': 4032, 'width': 3024, 'brand_id': 23}
#    2. {'id': 1, 'file_name': 'IMG_6467.JPG', 'height': 4032, 'width': 3024, 'brand_id': 47}
#    3. {'id': 2, 'file_name': 'IMG_6529.JPG', 'height': 4032, 'width': 3024, 'brand_id': 23}
#
# 🔹 字段: annotations
#    共 14955 项，前 3 项如下：
#    1. {'id': 0, 'image_id': 0, 'category_id': 21, 'bbox': [1043.818181818182, 604.6363636363635, 281.818181818182, 336.3636363636364], 'iscrowd': 0, 'area': 94793.38842975213, 'brand_id': 23}
#    2. {'id': 1, 'image_id': 0, 'category_id': 17, 'bbox': [2620.0, 3850.0, 131.0, 138.0], 'iscrowd': 0, 'area': 18078.0, 'brand_id': 23}
#    3. {'id': 2, 'image_id': 0, 'category_id': 17, 'bbox': [2663.0, 3187.0, 125.0, 126.0], 'iscrowd': 0, 'area': 15750.0, 'brand_id': 23}
#
# 🔹 字段: categories
#    共 23 项，前 3 项如下：
#    1. {'id': 0, 'name': 'bolt1', 'supercategory': 'component'}
#    2. {'id': 1, 'name': 'bolt2', 'supercategory': 'component'}
#    3. {'id': 2, 'name': 'bolt3', 'supercategory': 'component'}
#
# 📁 正在查看: val 数据集 -> val.json
# ✅ 顶级字段: ['images', 'annotations', 'categories', 'info', 'licenses']
#
# 🔹 字段: images
#    共 321 项，前 3 项如下：
#    1. {'id': 0, 'file_name': 'IMG_6886.JPG', 'height': 3024, 'width': 4032, 'brand_id': 33}
#    2. {'id': 1, 'file_name': 'IMG_6465.JPG', 'height': 4032, 'width': 3024, 'brand_id': 47}
#    3. {'id': 2, 'file_name': 'IMG_6892.JPG', 'height': 4032, 'width': 3024, 'brand_id': 33}
#
# 🔹 字段: annotations
#    共 3149 项，前 3 项如下：
#    1. {'id': 0, 'image_id': 0, 'category_id': 5, 'bbox': [1031.0, 1286.0, 31.0, 24.0], 'iscrowd': 0, 'area': 744.0, 'brand_id': 33}
#    2. {'id': 1, 'image_id': 0, 'category_id': 5, 'bbox': [1039.0, 1261.0, 29.0, 22.0], 'iscrowd': 0, 'area': 638.0, 'brand_id': 33}
#    3. {'id': 2, 'image_id': 0, 'category_id': 5, 'bbox': [913.0, 1372.0, 39.0, 23.0], 'iscrowd': 0, 'area': 897.0, 'brand_id': 33}
#
# 🔹 字段: categories
#    共 23 项，前 3 项如下：
#    1. {'id': 0, 'name': 'bolt1', 'supercategory': 'component'}
#    2. {'id': 1, 'name': 'bolt2', 'supercategory': 'component'}
#    3. {'id': 2, 'name': 'bolt3', 'supercategory': 'component'}
#
# 🔹 字段: info
#    类型: <class 'dict'>, 内容缩略: {'description': 'EV Bolt Dataset', 'version': '1.0', 'year': 2025, 'contributor': 'AutoFix', 'date_created': '2025-07-09'}
#
# 🔹 字段: licenses
#    共 1 项，前 3 项如下：
#    1. {'id': 1, 'name': 'MIT', 'url': 'https://opensource.org/licenses/MIT'}
